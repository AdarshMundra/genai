# %%
import random
class NakilLLM:
    def __init__(self):
        print("NakilLLM initialized")
    
    def __call__(self, messages):
        print("NakilLLM called")
        return random.choice(["Yes", "No"])

    def predict(self, messages):
        response_list = [
            "1",
            "2","3"
        ]
        print("NakilLLM called")
        return random.choice(response_list)

# %%
llm = NakilLLM()
# Out:
# NakilLLM initialized

# %%
llm.predict("")
# Out:
# NakilLLM called
# '2'

# %%
class NakliPrompt:
    def __init__(self,template,input_variables):
        self.template = template
        self.input_variables = input_variables
        print("NakliPrompt initialized")
    
    def format(self, input_dict):
        return self.template.format(**input_dict)

# %%
template = NakliPrompt(
    template=""" Write me a poem on {topic}""",
    input_variables=['topic']
    )
# Out:
# NakliPrompt initialized

# %%
template.format({"topic":"India"})
# Out:
# ' Write me a poem on India'

# %%
class NakliLLMChain:
    def __init__(self,llm,prompt):
        self.llm = llm
        self.prompt = prompt
    
    def __call__(self, messages):
        formatted_prompt = self.prompt.format(messages=messages)
        return self.llm(formatted_prompt)

    def run(self, input_dict):
        print(input_dict)
        final_prompt = self.prompt.format(**input_dict)
        print(final_prompt)
        # return self.llm(final_prompt)

# %%
llm = NakilLLM()
# Out:
# NakilLLM initialized

# %%
chain = NakliLLMChain(llm,tempalte)

# %%
chain.run({"topic":"India"})
# Out:
# {'topic': 'India'}
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 chain.run({"topic":"India"})
#
# Cell In[29], line 12, in NakliLLMChain.run(self, input_dict)
#      10 def run(self, input_dict):
#      11     print(input_dict)
# ---> 12     final_prompt = self.prompt.format(**input_dict)
#      13     print(final_prompt)
#
# TypeError: NakliPrompt.format() got an unexpected keyword argument 'topic'
